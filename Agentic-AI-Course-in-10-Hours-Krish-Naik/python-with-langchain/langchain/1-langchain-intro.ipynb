# %% [markdown]
# ### Langchain version v1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Agents

# %% [markdown]
# #### search_database Tool

# %%
from langchain.tools import tool

@tool
def search_database(query: str, limit: int = 10) -> str:
    """Search the customer database for records matching the query.

    Args:
        query: Search terms to look for
        limit: Maximum number of results to return
    """
    return f"Found {limit} results for '{query}'"

# %% [markdown]
# ### Create Agent

# %%
from langchain.agents import create_agent

agent= create_agent(
    model="gpt-5",
    tools=[search_database],
    system_prompt="You are a helpful assistant"
)

# %%
response = agent.invoke({"messages":[{"role":"user","content":"What is the capatial of india"}]})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 response = agent.invoke({"messages":[{"role":"user","content":"What is the capatial of india"}]})
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\pregel\main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
#    3882         config,
#    3883         context=context,
#    3884         stream_mode=(
#    3885             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3886         ),
#    3887         print_mode=print_mode,
#    3888         output_keys=output_keys,
#    3889         interrupt_before=interrupt_before,
#    3890         interrupt_after=interrupt_after,
#    3891         durability=durability,
#    3892         control=control,
#    3893         **kwargs,
#    3894     ):
#    3895         if stream_mode == "values":
#    3896             if len(chunk) == 2:
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\pregel\main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2934 for task in loop.match_cached_writes():
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#    2953 loop.after_tick()
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\pregel\_retry.py:585, in run_with_retry(task, retry_policy, configurable)
#     583     task.writes.clear()
#     584     # run the task
# --> 585     return task.proc.invoke(task.input, config)
#     586 except ParentCommand as exc:
#     587     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain\agents\factory.py:1332, in create_agent.<locals>.model_node(state, runtime)
#    1320 request = ModelRequest(
#    1321     model=model,
#    1322     tools=default_tools,
#    (...)   1328     runtime=runtime,
#    1329 )
#    1331 if wrap_model_call_handler is None:
# -> 1332     model_response = _execute_model_sync(request)
#    1333     return _build_commands(model_response)
#    1335 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain\agents\factory.py:1304, in create_agent.<locals>._execute_model_sync(request)
#    1301 if request.system_message:
#    1302     messages = [request.system_message, *messages]
# -> 1304 output = model_.invoke(messages)
#    1305 if name:
#    1306     output.name = name
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_core\runnables\base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\nitin\Desktop\dev\obsidian-notes\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# During task with name 'model' and id 'c27bec8b-d98c-fcf8-96a9-63343f25921b'
